# %%
import sys

# !{sys.executable} -m pip install --user ultralytics opencv-python-headless
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.240-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.7 MB/s
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#      |████████████████████████████████| 54.0 MB 210 kB/s
# Requirement already satisfied: pyyaml>=5.3.1 in /cm/local/apps/python39/lib/python3.9/site-packages (from ultralytics) (6.0.2)
# Collecting torchvision>=0.9.0
#   Downloading torchvision-0.23.0-cp39-cp39-manylinux_2_28_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 6.4 MB/s
# Collecting pillow>=7.1.2
#   Downloading pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 79.7 MB/s
# Requirement already satisfied: numpy>=1.23.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from ultralytics) (6.1.0)
# Collecting torch>=1.8.0
#   Downloading torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (888.0 MB)
#      |████████████████████████████████| 888.0 MB 2.8 kB/s
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#      |████████████████████████████████| 67.0 MB 10 kB/s
# Collecting matplotlib>=3.3.0
#   Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 85.1 MB/s
# Collecting ultralytics-thop>=2.0.18
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Requirement already satisfied: requests>=2.23.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from ultralytics) (2.32.3)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      |████████████████████████████████| 38.6 MB 54.5 MB/s
# Collecting polars>=0.20.0
#   Downloading polars-1.36.1-py3-none-any.whl (802 kB)
#      |████████████████████████████████| 802 kB 38.4 MB/s
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 88.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 79.5 MB/s
# Requirement already satisfied: pyparsing>=2.3.1 in /cm/local/apps/python39/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /cm/local/apps/python39/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
#      |████████████████████████████████| 321 kB 77.7 MB/s
# Collecting polars-runtime-32==1.36.1
#   Downloading polars_runtime_32-1.36.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.5 MB)
#      |████████████████████████████████| 44.5 MB 296 kB/s
# Requirement already satisfied: urllib3<3,>=1.21.1 in /cm/local/apps/python39/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /cm/local/apps/python39/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /cm/local/apps/python39/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /cm/local/apps/python39/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 71.8 MB/s
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      |████████████████████████████████| 594.3 MB 23 kB/s
# Collecting nvidia-nccl-cu12==2.27.3
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      |████████████████████████████████| 322.4 MB 52 kB/s
# Collecting fsspec
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 54.7 MB/s
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      |████████████████████████████████| 287.2 MB 16 kB/s
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      |████████████████████████████████| 39.3 MB 72.3 MB/s
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      |████████████████████████████████| 706.8 MB 11 kB/s
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      |████████████████████████████████| 267.5 MB 52 kB/s
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 51.3 MB/s
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      |████████████████████████████████| 88.0 MB 75.3 MB/s
# Requirement already satisfied: filelock in /cm/local/apps/python39/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 97.2 MB/s
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 75.9 MB/s
# Requirement already satisfied: jinja2 in /cm/shared/apps/jupyter/15.5.2/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      |████████████████████████████████| 89 kB 12.8 MB/s
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      |████████████████████████████████| 193.1 MB 22 kB/s
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      |████████████████████████████████| 954 kB 73.1 MB/s
# Collecting triton==3.4.0
#   Downloading triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
#      |████████████████████████████████| 155.4 MB 85 kB/s
# Requirement already satisfied: typing-extensions>=4.10.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      |████████████████████████████████| 63.6 MB 82.9 MB/s
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      |████████████████████████████████| 288.2 MB 8.3 kB/s
# Requirement already satisfied: setuptools>=40.8.0 in /cm/shared/apps/jupyter/15.5.2/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics) (59.4.0)
# Requirement already satisfied: importlib-metadata in /cm/local/apps/python39/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics) (8.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.21.0)
# Requirement already satisfied: six>=1.5 in /cm/local/apps/python39/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 76.7 MB/s
# Requirement already satisfied: MarkupSafe>=2.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-cusparse-cu12, nvidia-cublas-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparselt-cu12, nvidia-cusolver-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, networkx, fsspec, torch, polars-runtime-32, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, ultralytics-thop, torchvision, scipy, polars, opencv-python, matplotlib, ultralytics, opencv-python-headless

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 print("CUDA available:", torch.cuda.is_available())
#       3 print("GPU count:", torch.cuda.device_count())
#
# ModuleNotFoundError: No module named 'torch'

# %%
import sys

print("Python exe:", sys.executable)
# !{sys.executable} -m pip install torch --upgrade
# Out:
# Python exe: /cm/local/apps/python39/bin/python3.9
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Using cached torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (888.0 MB)
# Requirement already satisfied: jinja2 in /cm/shared/apps/jupyter/15.5.2/lib/python3.9/site-packages (from torch) (3.1.5)
# Requirement already satisfied: filelock in /cm/local/apps/python39/lib/python3.9/site-packages (from torch) (3.16.1)
# Collecting triton==3.4.0
#   Using cached triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.local/lib/python3.9/site-packages (from torch) (12.8.93)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.local/lib/python3.9/site-packages (from torch) (12.5.8.93)
# Collecting nvidia-nccl-cu12==2.27.3
#   Using cached nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.local/lib/python3.9/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from torch) (4.12.2)
# Collecting nvidia-curand-cu12==10.3.9.90
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Collecting nvidia-nvtx-cu12==12.8.90
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Collecting fsspec
#   Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: setuptools>=40.8.0 in /cm/shared/apps/jupyter/15.5.2/lib/python3.9/site-packages (from triton==3.4.0->torch) (59.4.0)
# Requirement already satisfied: importlib-metadata in /cm/local/apps/python39/lib/python3.9/site-packages (from triton==3.4.0->torch) (8.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.local/lib/python3.9/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cm/local/apps/python39/lib/python3.9/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /cm/local/apps/python39/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch) (3.21.0)
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparselt-cu12, nvidia-cusolver-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, networkx, fsspec, torch
#   WARNING: The scripts proton and proton-viewer are installed in '/home/hfygn2/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy is installed in '/home/hfygn2/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       3 print("CUDA available:", torch.cuda.is_available())
#       4 print("GPU count:", torch.cuda.device_count())
#
# ModuleNotFoundError: No module named 'torch'

# %%
import site, sys

print("USER_SITE:", site.USER_SITE)
print("Before:", len(sys.path))
sys.path.append(site.USER_SITE)
print("After:", len(sys.path))
# Out:
# USER_SITE: /home/hfygn2/.local/lib/python3.9/site-packages
# Before: 14
# After: 15

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       3 print("Torch version:", torch.__version__)
#       4 print("CUDA available:", torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'
